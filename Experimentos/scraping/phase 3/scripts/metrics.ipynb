# %%
import pandas as pd
import re

# %%
path_retrieved_html_wayback_sucess = '../data/retrieved_html_wayback_success.csv'
path_retrieved_html_wayback_fail = '../data/retrieved_html_wayback_fail.csv'

# %%
df_retrieved_html_wayback_sucess = pd.read_csv(path_retrieved_html_wayback_sucess)
df_retrieved_html_wayback_fail = pd.read_csv(path_retrieved_html_wayback_fail)

# %%
print(f"SUCESS: {len(df_retrieved_html_wayback_sucess)}")
print(f"FAIL: {len(df_retrieved_html_wayback_fail)}")
print(f"TOTAL: {len(df_retrieved_html_wayback_sucess) + len(df_retrieved_html_wayback_fail)}")
# Out:
# SUCESS: 4814
# FAIL: 1788
# TOTAL: 6602

# %%
#link com erro crítico (crashou na main)

link = "https://sbim.org.br/images/files/notas-tecnicas/nota-sbim-210916-suspensao-vacinacao-adolescentes-covid.pdf"

if link in df_retrieved_html_wayback_sucess['expanded_url'].values or link in df_retrieved_html_wayback_fail['expanded_url'].values:
    print(f"SUCESS: {link}")
# Out:
# SUCESS: https://sbim.org.br/images/files/notas-tecnicas/nota-sbim-210916-suspensao-vacinacao-adolescentes-covid.pdf

# %%
path_errors = "../logs/errors.txt"

with open(path_errors, 'r') as f:
    errors = f.readlines()

# %%
# extraindo os erros e quantas vezes eles ocorreram
pattern = r'Error:\s*(.+)'

erros = re.findall(pattern, ''.join(errors))

erros
# Out:
# ['Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro na API da Wayback Machine: Status 403',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro de conexão com Wayback Machine: HTTPSConnectionPool(host=\'web.archive.org\', port=443): Max retries exceeded with url: /cdx/search/cdx?url=https://www.ms.gov.br/defesa-civil-emite-alerta-de-temporal-e-queda-maior-que-5c-nas-temperaturas-em-municipios-da-regiao-sudoeste/&output=json&fl=timestamp,original&collapse=digest&limit=1&filter=statuscode:200&sort=reverse (Caused by ReadTimeoutError("HTTPSConnectionPool(host=\'web.archive.org\', port=443): Read timed out. (read timeout=15)"))',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao baixar HTML da Wayback Machine: HTTPSConnectionPool(host=\'web.archive.org\', port=443): Max retries exceeded with url: /web/20250407052210/https://www1.brasilemfolhas.com.br/ (Caused by ReadTimeoutError("HTTPSConnectionPool(host=\'web.archive.org\', port=443): Read timed out. (read timeout=15)"))',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao baixar HTML da Wayback Machine: HTTPSConnectionPool(host=\'web.archive.org\', port=443): Max retries exceeded with url: /web/20250407052210/https://www1.brasilemfolhas.com.br/ (Caused by ReadTimeoutError("HTTPSConnectionPool(host=\'web.archive.org\', port=443): Read timed out. (read timeout=15)"))',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro de conexão com Wayback Machine: HTTPSConnectionPool(host=\'web.archive.org\', port=443): Max retries exceeded with url: /cdx/search/cdx?url=https://www.campograndenews.com.br/cidades/capital/fim-de-semana-acaba-com-6-casos-de-violencia-contra-criancas&output=json&fl=timestamp,original&collapse=digest&limit=1&filter=statuscode:200&sort=reverse (Caused by ReadTimeoutError("HTTPSConnectionPool(host=\'web.archive.org\', port=443): Read timed out. (read timeout=15)"))',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao processar JSON da Wayback Machine',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao baixar HTML da Wayback Machine: HTTPSConnectionPool(host=\'web.archive.org\', port=443): Max retries exceeded with url: /web/20250407052210/https://www1.brasilemfolhas.com.br/ (Caused by ReadTimeoutError("HTTPSConnectionPool(host=\'web.archive.org\', port=443): Read timed out. (read timeout=15)"))',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  'Erro ao obter conteúdo HTML, sem contéudo',
#  ...]

# %%
string = "HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:"

# substituindo o conteúdo do erro pela string genérica
erros = [string if string in erro else erro for erro in erros]

# %%
for erro in erros:
    if erro == string:
        print(erro)
# Out:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:

# %%
# contando a quantidade de vezes que cada erro ocorreu
erros_count = pd.Series(erros).value_counts()
print(erros_count)
# Out:
# Erro ao obter conteúdo HTML, sem contéudo                                                1788
# Erro ao processar JSON da Wayback Machine                                                 102
# HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url:      13
# Erro na API da Wayback Machine: Status 403                                                  1
# Name: count, dtype: int64
